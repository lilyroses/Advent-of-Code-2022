# %% [markdown]
# # Day 5: Supply Stacks Solution
#
# - [Homepage](https://adventofcode.com/2022)
# - [Day 5 Challenge](https://adventofcode.com/2022/day/5)
# - [Input Data](https://adventofcode.com/2022/day/5/input)

# %% [markdown]
# ---
#
# ## Part I

# %%
from typing import List

# %% [markdown]
# ---
#
# ### Read Input Data and Parse Lines

# %%
input_file = 'input.txt'

# %% [markdown]
# ---
#
# #### ALL LINES

# %%
# Read in all lines from input data
with open(input_file, 'r') as f:
    lines = [line.strip('\n') for line in f.readlines()]
    
# lines

# %% [markdown]
# ---
#
# #### CRATE LINES

# %% [markdown]
# ##### Crate Rows (Lists)
#
# Parse the lines list to retrieve all lines contianing `[` characters,
# as these lines are the lines containing crate information.
#
# However, the final list of lists (`crate_rows`) does NOT preserve the
# bracket characters, and in fact purposely slices them out by using,
# list slicing (`line[1::4]`) to retrieve every 4th character from the
# `line` list.
#
# We know that every 4th character is the letter of the crate (or an
# empty space where there is no crate) from inspecting the lines
# containing crate information.

# %%
# Parse the lines with the crate information from 'lines' list

# Crate lines contain '[' characters, so first save those lines to
# crate_rows.

# Next, we extract just the crate's letters, removing brackets by
# slicing every fourth character from the line ([1::4]).

# Finally, replace the spaces in the line with . characters to preserve
# crate positions and to help with visual row representation.  
crate_rows = [[crates for crates in line[1::4].replace(' ', '.')]
               for line in lines if '[' in line]
                                                  
# crate_rows

# %% [markdown]
# ##### Crate Columns (Lists)
#
# `columns` is a list of lists, where each list contains each crate
# letter for that column.
#
# `crate_columns` takes each list in `crate_columns` and reverses
# it, so that the bottom-most crate for each column has an index of
# `0`, and the top-most crate has an index of `-1`.

# %%
# THIS WORKS!!!!

# Create CRATE COLUMN lists from the CRATE ROWS list using matrix
# transposing. Also, remove the '.' characters from the lists as we
# no longer need them to preserve crate position integrity
crate_columns_reversed = [[crate_row[i] for crate_row in crate_rows
                  if (crate_row[i] != '.')]
                 for i in range(len(crate_rows) + 1)]

# crate_columns_reversed

# %%
# Take all column lists and REVERSE them so that the BOTTOM
# CRATE has index 0 and the TOP CRATE has index -1
crate_columns = [column[::-1] for
                column in crate_columns_reversed]

# crate_columns

crate_columns
# Out:
# [['G', 'T', 'R', 'W'],
#  ['G', 'C', 'H', 'P', 'M', 'S', 'V', 'W'],
#  ['C', 'L', 'T', 'S', 'G', 'M'],
#  ['J', 'H', 'D', 'M', 'W', 'R', 'F'],
#  ['P', 'Q', 'L', 'H', 'S', 'W', 'F', 'J'],
#  ['P', 'J', 'D', 'N', 'F', 'M', 'S'],
#  ['Z', 'B', 'D', 'F', 'G', 'C', 'S', 'J'],
#  ['R', 'T', 'B'],
#  ['H', 'N', 'W', 'L', 'C']]

# %% [markdown]
# *Count the total number of crates for error checking later.*

# %%
# # DEBUG CELL
# def check_total_crates(cols):
#     total_crates = 0

#     for crate_column in crate_columns:
#         total_crates += len(crate_column)
    
#     return total_crates

# check_total_crates(crate_columns)

# %% [markdown]
# ---
#
# #### Move Lines
#
# Extract all the lines containing the move instructions from the
# `lines` list, by checking if the word `move` occurs in the line.
#
# Then, for each move line, extract all three numbers from the line
# using list slicing to pull every second word from the line.
#
# Change these string numbers to actual integers, save them to a list,
# `move_ints`, and save that list to a larger list, `moves`.

# %%
move_lines = [line for line in lines if 'move' in line]

# len(move_lines)
# move_lines

# %% [markdown]
# The lists of integers from the move lines.

# %%
moves = [[int(item) for item in
          move_line.split()[1::2]]
         for move_line in move_lines]

# len(moves)
# moves

# %% [markdown]
# ---
#
# ### Move the Crates

# %%
def move_crates(move):

      # Step 1: parse move into 3 parts:
    number_of_crates = move[0]
    start_column_index = move[1] - 1
    end_column_index = move[2] - 1
    
      # Step 2: fetch the crate column lists from the columns matrix:
    start_column_before = crate_columns[start_column_index]
    end_column_before = crate_columns[end_column_index]
    
      # Step 3: reverse the start_column list to pull crates from
      # the column
    start_column_reversed = start_column_before
    start_column_reversed.reverse()
    
      # Step 4: extract crates from start_column_reversed
    crates_to_move = start_column_reversed[0:number_of_crates]
    
      # Step 5: append crates on to end_column_before
    end_column_after = end_column_before + crates_to_move
  
      # Step 6: actually remove crates from start_column_before and
      # reverse start_column_after so that the crates will be in their
      # original order 
    start_column_after = start_column_reversed[number_of_crates:]
    start_column_after.reverse()

      # Step 7: update the crate_columns matrix with the updated
      # columns
    crate_columns[start_column_index] = start_column_after
    crate_columns[end_column_index] = end_column_after
    
    return crate_columns

# %%
# check_total_crates(crate_columns)

# %% [markdown]
# ---
#
# ### Execute the Moves

# %%
for move in moves:
    move_crates(move)

# %%
crate_columns

# %%
top_crates = ''

for crate_column in crate_columns:
    top_crate = crate_column[-1]
    top_crates += top_crate
    
top_crates

# %% [markdown]
# ### Answer

# %%
# (must clear all cell outputs and restart
# kernel to get correct answer if re-running the notebook)
ans = 'JCMHLVGMG'

print(ans)
# Out:
# JCMHLVGMG

# %% [markdown]
# ---
#
# ## Part II

# %%
def move_crate_stacks(move):

      # Step 1: parse move into 3 parts:
    number_of_crates = move[0]
    start_column_index = move[1] - 1
    end_column_index = move[2] - 1
    
      # Step 2: fetch the crate column lists from the columns matrix:
    start_column_before = crate_columns[start_column_index]
    end_column_before = crate_columns[end_column_index]
    
      # Step 3: reverse the start_column list to pull crates from
      # the column
    start_column_reversed = start_column_before
    start_column_reversed.reverse()
    
      # Step 4: extract crates from start_column_reversed
    crates_to_move = start_column_reversed[0:number_of_crates]
    crates_to_move.reverse()
    print(f'Crates to move: {crates_to_move}')
    
      # Step 5: append crates on to end_column_before
    end_column_after = end_column_before + crates_to_move
  
      # Step 6: actually remove crates from start_column_before and
      # reverse start_column_after so that the crates will be in their
      # original order 
    start_column_after = start_column_reversed[number_of_crates:]
    start_column_after.reverse()

      # Step 7: update the crate_columns matrix with the updated
      # columns
    crate_columns[start_column_index] = start_column_after
    crate_columns[end_column_index] = end_column_after
    
    return crate_columns

# %%
for move in moves:
    move_crate_stacks(move)
# Out:
# Crates to move: ['W', 'R', 'F']
# Crates to move: ['R', 'T', 'B']
# Crates to move: ['R', 'F']
# Crates to move: ['C', 'S', 'J']
# Crates to move: ['W']
# Crates to move: ['S', 'V', 'W', 'C', 'S', 'J']
# Crates to move: ['S', 'G', 'M', 'W', 'W']
# Crates to move: ['F']
# Crates to move: ['J', 'H', 'D', 'M']
# Crates to move: ['T', 'R']
# Crates to move: ['B', 'D', 'F', 'G', 'S', 'V', 'W', 'C', 'S', 'J']
# Crates to move: ['Z']
# Crates to move: ['L', 'H', 'S', 'W', 'F', 'J']
# Crates to move: ['G']
# Crates to move: ['B', 'S', 'G', 'M', 'W', 'W', 'F']
# Crates to move: ['T', 'J', 'H', 'D', 'M', 'B', 'D', 'F', 'G', 'S', 'V', 'W', 'C', 'S', 'J', 'B', 'S', 'G', 'M', 'W', 'W', 'F']
# Crates to move: ['T', 'R', 'Z']
# Crates to move: ['M', 'S', 'R', 'T']
# Crates to move: ['G', 'C', 'H', 'P', 'M']
# Crates to move: ['W', 'L', 'C']
# Crates to move: ['L', 'C']
# Crates to move: ['N']
# Crates to move: ['Q']
# Crates to move: ['N']
# Crates to move: ['P']
# Crates to move: ['P']
# Crates to move: ['W', 'W', 'F', 'W']
# Crates to move: ['P', 'M']
# Crates to move: ['H']
# Crates to move: ['F', 'W']
# Crates to move: ['H', 'P', 'M', 'F', 'W']
# Crates to move: ['W']
# Crates to move: ['P']
# Crates to move: ['W']
# Crates to move: ['J', 'D', 'N', 'F', 'N']
# Crates to move: ['W']
# Crates to move: ['P', 'W']
# Crates to move: ['F', 'N']
# Crates to move: ['D', 'N']
# Crates to move: ['R', 'L', 'H', 'S', 'W', 'F', 'J', 'T', 'R', 'Z', 'M', 'S', 'R', 'T', 'H', 'P', 'M', 'F', 'W', 'D', 'N']
# Crates to move: ['C', 'L', 'L', 'C', 'Q', 'H']
# Crates to move: ['J']
# Crates to move: ['H']
# Crates to move: ['H', 'P', 'M', 'F', 'W', 'D', 'N']
# Crates to move: ['L', 'C', 'Q']
# Crates to move: ['T', 'J', 'H', 'D', 'M', 'B', 'D', 'F', 'G', 'S', 'V', 'W', 'C', 'S', 'J', 'B', 'S', 'G', 'M', 'W', 'P', 'W', 'F', 'N']
# Crates to move: ['C', 'C', 'L']
# Crates to move: ['W', 'F', 'J', 'T', 'R', 'Z', 'M', 'S', 'R', 'T']
# Crates to move: ['G']
# Crates to move: ['L']
# Crates to move: ['J', 'L', 'C', 'Q', 'L']
# Crates to move: ['R', 'Z', 'M', 'S', 'R', 'T', 'J', 'L', 'C', 'Q', 'L']
# Crates to move: ['G']
# Crates to move: ['G']
# Crates to move: ['S']
# Crates to move: ['V', 'W', 'C', 'S', 'J', 'B', 'S', 'G', 'M', 'W', 'P', 'W', 'F', 'N', 'W', 'F', 'J', 'T', 'G']
# Crates to move: ['G']
# Crates to move: ['Z', 'M', 'S', 'R', 'T', 'J', 'L', 'C', 'Q', 'L']
# Crates to move: ['C', 'C', 'R']
# Crates to move: ['H']
# Crates to move: ['G']
# Crates to move: ['S', 'G', 'M', 'W', 'P', 'W', 'F', 'N', 'W', 'F', 'J', 'T', 'G', 'Z', 'M', 'S', 'R', 'T', 'J', 'L', 'C', 'Q', 'L']
# Crates to move: ['B']
# Crates to move: ['H']
# Crates to move: ['H', 'H']
# Crates to move: ['D', 'F', 'G', 'S', 'C', 'C', 'R']
# Crates to move: ['D', 'N', 'T', 'J', 'H', 'D', 'M', 'B']
# Crates to move: ['G', 'Z', 'M', 'S', 'R', 'T', 'J', 'L', 'C', 'Q', 'L']
# Crates to move: ['R', 'L']
# Crates to move: ['P']
# Crates to move: ['P', 'M', 'F', 'W', 'R', 'L', 'P']
# Crates to move: ['H']
# Crates to move: ['H']
# Crates to move: ['M', 'W', 'P', 'W', 'F', 'N', 'W', 'F', 'J', 'T']
# Crates to move: ['T', 'J', 'L', 'C', 'Q', 'L']
# Crates to move: ['G', 'Z', 'M', 'S', 'R']
# Crates to move: ['L', 'C', 'Q', 'L']
# Crates to move: ['J']
# Crates to move: ['M', 'B', 'H', 'M', 'W', 'P', 'W', 'F', 'N', 'W', 'F', 'J', 'T']
# Crates to move: ['G']
# Crates to move: ['G']
# Crates to move: ['S', 'R']
# Crates to move: ['G', 'Z', 'M']
# Crates to move: ['T', 'G']
# Crates to move: ['G']
# Crates to move: ['L', 'J']
# Crates to move: ['L', 'J']
# Crates to move: ['C', 'Q']
# Crates to move: ['L', 'J']
# Crates to move: ['S', 'G']
# Crates to move: ['T', 'J', 'H', 'D']
# Crates to move: ['L', 'S', 'G']
# Crates to move: ['S', 'R', 'G', 'Z', 'M', 'L', 'S', 'G']
# Crates to move: ['G']
# Crates to move: ['J', 'H', 'D']
# Crates to move: ['T', 'L', 'J', 'T']
# Crates to move: ['G']
# Crates to move: ['C', 'S', 'J', 'D', 'F', 'G', 'S', 'C', 'C', 'R', 'D', 'N']
# Crates to move: ['W', 'F', 'J', 'T', 'C', 'Q', 'J', 'H', 'D']
# Crates to move: ['H']
# Crates to move: ['S', 'V', 'W']
# Crates to move: ['C', 'S', 'J', 'D', 'F', 'G', 'S', 'C', 'C', 'R', 'D', 'N']
# Crates to move: ['G']
# Crates to move: ['W']
# Crates to move: ['V']
# Crates to move: ['W']
# Crates to move: ['M', 'F', 'W', 'R', 'L', 'P', 'M', 'B', 'H', 'M', 'W', 'P', 'W', 'F', 'N', 'G']
# Crates to move: ['P']
# Crates to move: ['S', 'P']
# Crates to move: ['C', 'C', 'R', 'D', 'N', 'S', 'P']
# Crates to move: ['W']
# Crates to move: ['V']
# Crates to move: ['J', 'T']
# Crates to move: ['W']
# Crates to move: ['R', 'G', 'Z', 'M', 'L', 'S', 'T', 'L']
# Crates to move: ['R', 'D', 'N', 'S', 'P']
# Crates to move: ['S', 'R', 'G', 'Z', 'M', 'L', 'S', 'T', 'L']
# Crates to move: ['P', 'M', 'B', 'H', 'M', 'W', 'P', 'W', 'F', 'N', 'G', 'V']
# Crates to move: ['S', 'P']
# Crates to move: ['C', 'S', 'J', 'D', 'F', 'G']
# Crates to move: ['M', 'F', 'W', 'R', 'L']
# Crates to move: ['C', 'C']
# Crates to move: ['S', 'R', 'G', 'Z', 'M', 'L', 'S', 'T', 'L', 'C', 'C']
# Crates to move: ['W']
# Crates to move: ['D', 'N']
# Crates to move: ['T', 'M', 'F', 'W', 'R', 'L', 'W']
# Crates to move: ['H', 'D', 'N']
# Crates to move: ['J', 'H', 'D']
# Crates to move: ['P', 'W', 'F', 'N', 'G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'S', 'T', 'L', 'C', 'C']
# Crates to move: ['J', 'T', 'C', 'Q']
# Crates to move: ['F', 'G']
# Crates to move: ['J']
# Crates to move: ['W']
# Crates to move: ['J']
# Crates to move: ['B', 'H', 'G', 'S', 'C', 'S', 'J', 'D']
# Crates to move: ['W']
# Crates to move: ['W']
# Crates to move: ['T', 'L', 'C', 'C']
# Crates to move: ['R', 'T', 'M', 'F', 'W', 'R', 'L', 'W']
# Crates to move: ['Q', 'J', 'T', 'L', 'C', 'C']
# Crates to move: ['T', 'L', 'C', 'C']
# Crates to move: ['G', 'T', 'L', 'C', 'C']
# Crates to move: ['P', 'W', 'F', 'N', 'G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'S']
# Crates to move: ['P', 'M', 'B', 'H', 'M', 'W', 'Q', 'J']
# Crates to move: ['T', 'M', 'F', 'W', 'R', 'L', 'W']
# Crates to move: ['J', 'H', 'D']
# Crates to move: ['L', 'W']
# Crates to move: ['L', 'W']
# Crates to move: ['R']
# Crates to move: ['T', 'L', 'C', 'C', 'T', 'M', 'F', 'W', 'R']
# Crates to move: ['M', 'F', 'W', 'R']
# Crates to move: ['C', 'T']
# Crates to move: ['W', 'R']
# Crates to move: ['T', 'L', 'C']
# Crates to move: ['L', 'W', 'C', 'T']
# Crates to move: ['H', 'D', 'N', 'J', 'T', 'C', 'G']
# Crates to move: ['T', 'L', 'C']
# Crates to move: ['J', 'T', 'C', 'G']
# Crates to move: ['C', 'T']
# Crates to move: ['J', 'J', 'H', 'D', 'R', 'H', 'D', 'N']
# Crates to move: ['S']
# Crates to move: ['S']
# Crates to move: ['G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'S']
# Crates to move: ['T', 'C', 'G']
# Crates to move: ['J']
# Crates to move: ['G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'S']
# Crates to move: ['W', 'F', 'F', 'P', 'W', 'F', 'N']
# Crates to move: ['G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'S']
# Crates to move: ['M', 'B', 'H', 'M', 'W', 'Q']
# Crates to move: ['J', 'J', 'H', 'D', 'R', 'H', 'D', 'N']
# Crates to move: ['L', 'C', 'C', 'T']
# Crates to move: ['C', 'C', 'T']
# Crates to move: ['J', 'J', 'H', 'D', 'R', 'H', 'D', 'N']
# Crates to move: ['G', 'S', 'C', 'S', 'J', 'D', 'P']
# Crates to move: ['M', 'B', 'H', 'M', 'W', 'Q', 'L']
# Crates to move: ['H', 'D', 'N']
# Crates to move: ['B', 'H']
# Crates to move: ['G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'S', 'J', 'J', 'H', 'D', 'R']
# Crates to move: ['G', 'S', 'C', 'S', 'J', 'D', 'P']
# Crates to move: ['D', 'N']
# Crates to move: ['T', 'H']
# Crates to move: ['C']
# Crates to move: ['N']
# Crates to move: ['C', 'N']
# Crates to move: ['C']
# Crates to move: ['N']
# Crates to move: ['C']
# Crates to move: ['C']
# Crates to move: ['T', 'M', 'B', 'H', 'M', 'W', 'Q', 'L']
# Crates to move: ['N']
# Crates to move: ['S', 'J', 'J', 'H', 'D', 'R', 'G', 'S', 'C', 'S', 'J', 'D', 'P', 'T', 'H']
# Crates to move: ['F', 'N', 'B', 'H']
# Crates to move: ['C']
# Crates to move: ['M', 'F', 'T', 'C', 'G', 'J', 'W', 'F', 'F', 'P', 'W']
# Crates to move: ['R', 'G', 'S', 'C', 'S', 'J', 'D', 'P', 'T', 'H', 'M', 'F', 'T', 'C', 'G', 'J', 'W', 'F', 'F', 'P', 'W']
# Crates to move: ['C']
# Crates to move: ['J', 'H', 'D', 'C']
# Crates to move: ['N']
# Crates to move: ['N']
# Crates to move: ['W', 'R', 'L', 'W', 'G', 'V', 'S', 'P', 'S', 'R', 'G', 'Z', 'M', 'L', 'F', 'N', 'B', 'H', 'C']
# Crates to move: ['F', 'N', 'B', 'H', 'C']
# Crates to move: ['M', 'W', 'Q', 'L', 'J', 'H', 'D', 'C']
# Crates to move: ['P', 'W', 'M', 'W', 'Q', 'L', 'J', 'H', 'D', 'C']
# Crates to move: ['D', 'T', 'M', 'B', 'H']
# Crates to move: ['H', 'C']
# Crates to move: ['W', 'F', 'F']
# Crates to move: ['W', 'F', 'F']
# Crates to move: ['H']
# Crates to move: ['C', 'S', 'J', 'D', 'P', 'T', 'H', 'M', 'F', 'T', 'C', 'G', 'J']
# Crates to move: ['G', 'S']
# Crates to move: ['Z', 'M', 'L', 'P', 'W', 'M', 'W', 'Q', 'L', 'J', 'H', 'D', 'C', 'W', 'F', 'F', 'H']
# Crates to move: ['R']
# Crates to move: ['G', 'R']
# Crates to move: ['G', 'R']
# Crates to move: ['T', 'M', 'B', 'G', 'R']
# Crates to move: ['S', 'R']
# Crates to move: ['S', 'J', 'W', 'R', 'L', 'W', 'G', 'V', 'S', 'P']
# Crates to move: ['W', 'M', 'W', 'Q', 'L', 'J', 'H', 'D', 'C', 'W', 'F', 'F', 'H', 'T', 'M', 'B', 'G', 'R']
# Crates to move: ['J', 'H', 'D', 'C', 'W', 'F', 'F', 'H', 'T', 'M', 'B', 'G', 'R']
# Crates to move: ['S', 'R', 'W', 'M', 'W', 'Q', 'L']
# Crates to move: ['Q', 'L']
# Crates to move: ['Z', 'M', 'L', 'P']
# Crates to move: ['W']
# Crates to move: ['M']
# Crates to move: ['N', 'B']
# Crates to move: ['D']
# Crates to move: ['S']
# Crates to move: ['B']
# Crates to move: ['J', 'D', 'P', 'T', 'H', 'M', 'F', 'T', 'C', 'G', 'J']
# Crates to move: ['S']
# Crates to move: ['M', 'B', 'G', 'R', 'Q', 'L', 'N']
# Crates to move: ['Z', 'M', 'L', 'P', 'M']
# Crates to move: ['B']
# Crates to move: ['P', 'M', 'B']
# Crates to move: ['F', 'F', 'H', 'T', 'P', 'M', 'B']
# Crates to move: ['P', 'J', 'H', 'D', 'C', 'W']
# Crates to move: ['R', 'L', 'W', 'G', 'V', 'S']
# Crates to move: ['J', 'W']
# Crates to move: ['G', 'R', 'Q', 'L', 'N']
# Crates to move: ['W']
# Crates to move: ['J']
# Crates to move: ['S', 'M', 'B', 'J']
# Crates to move: ['S']
# Crates to move: ['W']
# Crates to move: ['R', 'L', 'W', 'G', 'V', 'S', 'W']
# Crates to move: ['S']
# Crates to move: ['G']
# Crates to move: ['N', 'R', 'L', 'W', 'G', 'V', 'S', 'W']
# Crates to move: ['S', 'M', 'B', 'J', 'G']
# Crates to move: ['M', 'B', 'J', 'G']
# Crates to move: ['H', 'C', 'S']
# Crates to move: ['C', 'S', 'J']
# Crates to move: ['L']
# Crates to move: ['V', 'S', 'W']
# Crates to move: ['D', 'C', 'W', 'W', 'M', 'B', 'J', 'G', 'H', 'C', 'S', 'C', 'S', 'J', 'L']
# Crates to move: ['W', 'M', 'B', 'J', 'G', 'H', 'C', 'S', 'C', 'S', 'J', 'L']
# Crates to move: ['M', 'L', 'G', 'R', 'Q', 'V', 'S', 'W']
# Crates to move: ['S', 'J', 'L']
# Crates to move: ['S', 'J', 'L']
# Crates to move: ['H']
# Crates to move: ['W', 'M', 'B', 'J', 'G', 'H', 'C', 'S', 'C']
# Crates to move: ['H', 'C', 'S', 'C']
# Crates to move: ['S', 'C']
# Crates to move: ['B', 'P', 'J']
# Crates to move: ['T', 'P', 'M']
# Crates to move: ['H', 'C']
# Crates to move: ['Z']
# Crates to move: ['J', 'G']
# Crates to move: ['M', 'F', 'T', 'C', 'G', 'B', 'P', 'J', 'T', 'P', 'M', 'J', 'G']
# Crates to move: ['G', 'R', 'Q', 'V', 'S', 'W', 'H', 'H', 'C', 'M', 'F', 'T', 'C', 'G', 'B', 'P', 'J', 'T', 'P', 'M', 'J', 'G']
# Crates to move: ['L', 'S', 'C']
# Crates to move: ['B']
# Crates to move: ['M']
# Crates to move: ['S', 'C']
# Crates to move: ['W', 'S', 'C']
# Crates to move: ['F', 'F', 'H', 'Z', 'B']
# Crates to move: ['S', 'C']
# Crates to move: ['C', 'W', 'S', 'J']
# Crates to move: ['M', 'L']
# Crates to move: ['C', 'W', 'S', 'J']
# Crates to move: ['M', 'L']
# Crates to move: ['D', 'C', 'W', 'S', 'J', 'M', 'L']
# Crates to move: ['D', 'P', 'T', 'H', 'F', 'F', 'H', 'Z', 'B']
# Crates to move: ['S', 'J', 'M', 'L']
# Crates to move: ['H', 'Z', 'B']
# Crates to move: ['T', 'C', 'G', 'B', 'P', 'J', 'T', 'P', 'M', 'J', 'G', 'M']
# Crates to move: ['R', 'W', 'D', 'C', 'W']
# Crates to move: ['W']
# Crates to move: ['F']
# Crates to move: ['H', 'H', 'C', 'M']
# Crates to move: ['Z', 'B']
# Crates to move: ['P', 'M', 'J', 'G', 'M', 'R', 'W', 'D', 'C', 'W', 'F']
# Crates to move: ['S', 'C', 'H']
# Crates to move: ['H', 'C', 'M', 'Z', 'B', 'S', 'C', 'H']
# Crates to move: ['Z', 'B', 'S', 'C', 'H']
# Crates to move: ['C', 'M']
# Crates to move: ['H']
# Crates to move: ['F', 'F', 'C', 'M']
# Crates to move: ['R', 'W', 'D', 'C', 'W', 'F']
# Crates to move: ['H']
# Crates to move: ['D', 'P', 'T', 'H', 'H']
# Crates to move: ['C', 'H', 'H']
# Crates to move: ['M']
# Crates to move: ['S', 'W']
# Crates to move: ['R', 'L', 'W', 'G']
# Crates to move: ['Z', 'B', 'S']
# Crates to move: ['J', 'G', 'M', 'C', 'H', 'H']
# Crates to move: ['J', 'G', 'M', 'C', 'H', 'H']
# Crates to move: ['C', 'Z', 'B', 'S']
# Crates to move: ['T', 'M', 'C', 'Z', 'B', 'S']
# Crates to move: ['W', 'G']
# Crates to move: ['R', 'L']
# Crates to move: ['M', 'C', 'H', 'H']
# Crates to move: ['F']
# Crates to move: ['Z', 'B', 'S', 'R', 'L']
# Crates to move: ['F']
# Crates to move: ['G']
# Crates to move: ['V', 'S', 'W', 'P', 'M', 'F', 'G']
# Crates to move: ['D', 'C', 'W', 'F', 'S', 'W']
# Crates to move: ['S', 'J', 'M', 'L', 'R', 'W']
# Crates to move: ['H', 'H', 'M', 'C', 'H', 'H', 'Z', 'B', 'S', 'R', 'L', 'D', 'C', 'W', 'F', 'S', 'W']
# Crates to move: ['P', 'M', 'F', 'G']
# Crates to move: ['G', 'R', 'Q']
# Crates to move: ['D', 'J', 'D', 'P', 'T']
# Crates to move: ['J', 'M', 'L', 'R', 'W']
# Crates to move: ['L', 'T', 'M', 'C', 'V', 'S', 'W']
# Crates to move: ['N', 'J', 'J', 'M', 'L', 'R', 'W']
# Crates to move: ['W', 'F', 'S', 'W']
# Crates to move: ['T', 'M', 'C', 'V', 'S', 'W']
# Crates to move: ['N', 'F']
# Crates to move: ['F', 'G']
# Crates to move: ['G']
# Crates to move: ['F']
# Crates to move: ['S', 'F']
# Crates to move: ['P', 'M', 'S', 'F']
# Crates to move: ['F']
# Crates to move: ['B', 'P', 'J', 'W', 'G']
# Crates to move: ['W']
# Crates to move: ['Z', 'B', 'S', 'R', 'L', 'D', 'C']
# Crates to move: ['H', 'H', 'M', 'C', 'H', 'H']
# Crates to move: ['W', 'G', 'P', 'M', 'S', 'F', 'B', 'P', 'J', 'W', 'G']
# Crates to move: ['F', 'N']
# Crates to move: ['V', 'S', 'H', 'H', 'M', 'C', 'H', 'H']
# Crates to move: ['B', 'P', 'J', 'W', 'G']
# Crates to move: ['G', 'P', 'M', 'S', 'F']
# Crates to move: ['H']
# Crates to move: ['S', 'F']
# Crates to move: ['W']
# Crates to move: ['S', 'F']
# Crates to move: ['L', 'R', 'W', 'V', 'S', 'H', 'H', 'M', 'C', 'H']
# Crates to move: ['M', 'S', 'F']
# Crates to move: ['H']
# Crates to move: ['H', 'H', 'M', 'C']
# Crates to move: ['H', 'L', 'R', 'W', 'V', 'S']
# Crates to move: ['W', 'F', 'S']
# Crates to move: ['G', 'R', 'Q', 'D', 'J', 'D', 'P', 'T', 'L', 'F', 'Z', 'B', 'S', 'R', 'L', 'D', 'C', 'F', 'N']
# Crates to move: ['C', 'W', 'F', 'S', 'G', 'R', 'Q', 'D', 'J', 'D', 'P', 'T', 'L', 'F', 'Z', 'B', 'S', 'R', 'L', 'D', 'C', 'F', 'N']
# Crates to move: ['M']
# Crates to move: ['M']
# Crates to move: ['M']
# Crates to move: ['M']
# Crates to move: ['L', 'D', 'C', 'F', 'N']
# Crates to move: ['T']
# Crates to move: ['H', 'H', 'H', 'M', 'C']
# Crates to move: ['H', 'H', 'M', 'C']
# Crates to move: ['R']
# Crates to move: ['T', 'L', 'F', 'Z', 'B', 'S']
# Crates to move: ['J', 'M']
# Crates to move: ['R']
# Crates to move: ['M']
# Crates to move: ['M']
# Crates to move: ['J']
# Crates to move: ['R', 'Q', 'D', 'J', 'D', 'P']
# Crates to move: ['P', 'H', 'H', 'M', 'C']
# Crates to move: ['F', 'N', 'T', 'H', 'J', 'P', 'H', 'H', 'M', 'C']
# Crates to move: ['J', 'W', 'G', 'W', 'M', 'S', 'F', 'L', 'D', 'C']
# Crates to move: ['H', 'L', 'R', 'W', 'V', 'S', 'C', 'W', 'F', 'S', 'G']
# Crates to move: ['F', 'L', 'D', 'C']
# Crates to move: ['S', 'N', 'F', 'N', 'T', 'H', 'J', 'P', 'H', 'H', 'M', 'C', 'J', 'W', 'G', 'W', 'M', 'S']
# Crates to move: ['D', 'C']
# Crates to move: ['S', 'R', 'M']
# Crates to move: ['G']
# Crates to move: ['L']
# Crates to move: ['Q', 'D', 'J', 'D', 'P', 'L']
# Crates to move: ['T', 'C', 'G', 'W', 'B', 'P']
# Crates to move: ['T', 'H', 'J', 'P', 'H', 'H', 'M', 'C', 'J', 'W', 'G', 'W', 'M', 'S', 'D', 'C', 'S', 'R', 'M']
# Crates to move: ['V', 'S', 'C', 'W', 'F', 'S', 'G']
# Crates to move: ['F']
# Crates to move: ['J', 'M', 'R', 'F']
# Crates to move: ['S', 'G']
# Crates to move: ['L', 'R', 'W']
# Crates to move: ['H']
# Crates to move: ['W', 'B', 'P', 'J', 'M', 'R', 'F']
# Crates to move: ['F', 'W', 'B', 'P', 'J', 'M', 'R', 'F']
# Crates to move: ['H']
# Crates to move: ['S', 'G']
# Crates to move: ['M', 'R', 'F']
# Crates to move: ['G']
# Crates to move: ['B', 'P', 'J']
# Crates to move: ['W', 'M', 'R', 'F']
# Crates to move: ['H', 'B', 'P', 'J']
# Crates to move: ['M', 'R', 'F']
# Crates to move: ['F', 'N', 'W']
# Crates to move: ['T', 'C', 'G', 'M', 'R', 'F']
# Crates to move: ['V', 'S', 'C', 'W', 'F', 'N', 'W', 'T', 'C', 'G', 'M', 'R', 'F']
# Crates to move: ['L', 'F', 'Z', 'B', 'G']
# Crates to move: ['R']
# Crates to move: ['R']
# Crates to move: ['L']
# Crates to move: ['R']
# Crates to move: ['L']
# Crates to move: ['S', 'N']
# Crates to move: ['B', 'P', 'J']
# Crates to move: ['T']
# Crates to move: ['M', 'S', 'D', 'C', 'S', 'R', 'M', 'L', 'F', 'Z', 'B', 'G', 'R']
# Crates to move: ['W', 'V', 'S', 'C', 'W', 'F', 'N', 'W', 'T', 'C', 'G', 'M', 'R', 'F']
# Crates to move: ['L', 'S', 'N', 'B', 'P', 'J']
# Crates to move: ['Z', 'B', 'G', 'R']
# Crates to move: ['F']
# Crates to move: ['S']
# Crates to move: ['C', 'J', 'W', 'G', 'W']
# Crates to move: ['R', 'M', 'L', 'F']
# Crates to move: ['S', 'C', 'W', 'F', 'N', 'W', 'T', 'C', 'G', 'M', 'R', 'F']
# Crates to move: ['F']
# Crates to move: ['F', 'N', 'W', 'T', 'C', 'G', 'M', 'R', 'F']
# Crates to move: ['H', 'M', 'R', 'M', 'L', 'F', 'S', 'C', 'W']
# Crates to move: ['H']
# Crates to move: ['P', 'L', 'T', 'H', 'J', 'P']
# Crates to move: ['S', 'D', 'C', 'S', 'F']
# Crates to move: ['Q', 'D', 'J', 'D', 'S', 'D', 'C', 'S', 'F']
# Crates to move: ['G', 'M', 'R', 'F']
# Crates to move: ['D', 'J', 'D', 'S', 'D', 'C', 'S', 'F']
# Crates to move: ['R', 'Q']
# Crates to move: ['T', 'C']
# Crates to move: ['S']
# Crates to move: ['G', 'H']
# Crates to move: ['W']
# Crates to move: ['G', 'S']
# Crates to move: ['W', 'G', 'S']
# Crates to move: ['D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q']
# Crates to move: ['M', 'R', 'M', 'L', 'F', 'S', 'C', 'W', 'H']
# Crates to move: ['C', 'J', 'W', 'G', 'W', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q']
# Crates to move: ['Z', 'B', 'W', 'G', 'S', 'C', 'J', 'W', 'G', 'W', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q']
# Crates to move: ['W', 'V', 'H', 'Z', 'B', 'W', 'G', 'S', 'C', 'J', 'W', 'G', 'W', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q']
# Crates to move: ['Z', 'B', 'W', 'G', 'S', 'C', 'J', 'W', 'G', 'W', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q']
# Crates to move: ['H']
# Crates to move: ['T', 'C']
# Crates to move: ['H']
# Crates to move: ['J', 'T', 'C']
# Crates to move: ['B', 'P']
# Crates to move: ['R', 'F', 'G', 'H', 'M', 'R', 'M', 'L', 'F', 'S', 'C', 'W', 'H']
# Crates to move: ['L', 'S', 'N']
# Crates to move: ['R', 'F', 'G', 'H', 'M', 'R', 'M', 'L', 'F', 'S', 'C', 'W', 'H']
# Crates to move: ['L', 'S', 'N']
# Crates to move: ['V', 'H', 'J', 'T', 'C']
# Crates to move: ['C', 'W', 'H', 'L', 'S', 'N']
# Crates to move: ['T']
# Crates to move: ['W', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q']
# Crates to move: ['G']
# Crates to move: ['T', 'C']
# Crates to move: ['T', 'C']
# Crates to move: ['F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q', 'G']
# Crates to move: ['C', 'J', 'W']
# Crates to move: ['C', 'C', 'J', 'W']
# Crates to move: ['F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q', 'G', 'C', 'C', 'J', 'W']
# Crates to move: ['T']
# Crates to move: ['W', 'G', 'S']
# Crates to move: ['S']
# Crates to move: ['G']
# Crates to move: ['G', 'H', 'M', 'R', 'M', 'L', 'F', 'S', 'T']
# Crates to move: ['M', 'R', 'M', 'L', 'F', 'S', 'T']
# Crates to move: ['R', 'F']
# Crates to move: ['T', 'W']
# Crates to move: ['B', 'M', 'R', 'M', 'L', 'F', 'S', 'T']
# Crates to move: ['W', 'W', 'G', 'H', 'R', 'F']
# Crates to move: ['P']
# Crates to move: ['L', 'S', 'N', 'G']
# Crates to move: ['C', 'C', 'J', 'W', 'T', 'W']
# Crates to move: ['J', 'P', 'G', 'M', 'C', 'W', 'H']
# Crates to move: ['T', 'H']
# Crates to move: ['M', 'Z']
# Crates to move: ['W', 'W', 'G', 'H', 'R', 'F', 'P', 'T', 'H']
# Crates to move: ['W', 'W', 'G', 'H', 'R', 'F', 'P', 'T', 'H']
# Crates to move: ['P', 'L']
# Crates to move: ['V', 'H', 'J', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q', 'G']
# Crates to move: ['T', 'V', 'H', 'J', 'F', 'N', 'D', 'S', 'D', 'C', 'S', 'F', 'R', 'Q', 'G']
# Crates to move: ['J']
# Crates to move: ['B', 'C', 'C', 'J', 'W', 'T', 'W']
# Crates to move: ['M', 'Z']
# Crates to move: ['T', 'W']
# Crates to move: ['W']
# Crates to move: ['P', 'L']
# Crates to move: ['S', 'F', 'R', 'Q', 'G', 'M', 'Z']
# Crates to move: ['S']
# Crates to move: ['S', 'F', 'R', 'Q', 'G', 'M', 'Z']
# Crates to move: ['S']
# Crates to move: ['L']
# Crates to move: ['F', 'P', 'T', 'H', 'W', 'S']
# Crates to move: ['H', 'J', 'F', 'N', 'D', 'S', 'D', 'C', 'L']
# Crates to move: ['Z']
# Crates to move: ['J', 'T', 'W']

# %%
top_crates_2 = ''

for crate_column in crate_columns:
    top_crates_2 += crate_column[-1]
    
top_crates_2
# Out:
# 'LVMRWSSPZ'

# %% [markdown]
# ### Answer

# %%
ans = 'LVMRWSSPZ'

print(ans)
# Out:
# LVMRWSSPZ
