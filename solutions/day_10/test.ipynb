# %%
# INPUT_FILE = 'test.txt'
INPUT_FILE = 'input.txt'

with open(INPUT_FILE, 'r') as f:
    lines = [line.strip() for line in f.readlines()]

# lines

# %%
test_input = [
'addx 15',
'addx -11',
'addx 6',
'addx -3',
'addx 5',
'addx -1',
'addx -8',
'addx 13',
'addx 4',
'noop',
'addx -1',
'addx 5',
'addx -1',
'addx 5',
'addx -1',
'addx 5',
'addx -1',
'addx 5',
'addx -1',
'addx -35',
'addx 1',
'addx 24',
'addx -19',
'addx 1',
'addx 16',
'addx -11',
'noop',
'noop',
'addx 21',
'addx -15',
'noop',
'noop',
'addx -3',
'addx 9',
'addx 1',
'addx -3',
'addx 8',
'addx 1',
'addx 5',
'noop',
'noop',
'noop',
'noop',
'noop',
'addx -36',
'noop',
'addx 1',
'addx 7',
'noop',
'noop',
'noop',
'addx 2',
'addx 6',
'noop',
'noop',
'noop',
'noop',
'noop',
'addx 1',
'noop',
'noop',
'addx 7',
'addx 1',
'noop',
'addx -13',
'addx 13',
'addx 7',
'noop',
'addx 1',
'addx -33',
'noop',
'noop',
'noop',
'addx 2',
'noop',
'noop',
'noop',
'addx 8',
'noop',
'addx -1',
'addx 2',
'addx 1',
'noop',
'addx 17',
'addx -9',
'addx 1',
'addx 1',
'addx -3',
'addx 11',
'noop',
'noop',
'addx 1',
'noop',
'addx 1',
'noop',
'noop',
'addx -13',
'addx -19',
'addx 1',
'addx 3',
'addx 26',
'addx -30',
'addx 12',
'addx -1',
'addx 3',
'addx 1',
'noop',
'noop',
'noop',
'addx -9',
'addx 18',
'addx 1',
'addx 2',
'noop',
'noop',
'addx 9',
'noop',
'noop',
'noop',
'addx -1',
'addx 2',
'addx -37',
'addx 1',
'addx 3',
'noop',
'addx 15',
'addx -21',
'addx 22',
'addx -6',
'addx 1',
'noop',
'addx 2',
'addx 1',
'noop',
'addx -10',
'noop',
'noop',
'addx 20',
'addx 1',
'addx 2',
'addx 2',
'addx -6',
'addx -11',
'noop',
'noop',
'noop'
]

# %%
ns = list(range(1, 600))
for n in ns:
    if (n == 20 or (n - 20) % 40 == 0) and n <= 220:
        print(n)
# Out:
# 20
# 60
# 100
# 140
# 180
# 220

# %%
X = 1
cycles = 0
vals = []

def cycle():
    global cycles
    global vals
    cycles += 1
    if cycles == 20 or (cycles - 20) % 40 == 0 and cycles <= 220:
        vals.append(X * cycles)

    # Remove this after
    print(f"cycles={cycles}")
    print(f"X={X}")


def addx(V):
    global cycles
    global X
    cycle()
    cycle()
    X += V
    

def noop():
    cycle()



cycle_values = []

for line in lines:
    if 'addx' in line:
        V = int(line.split()[-1])
        addx(V)
    else:
        noop()
        # print(cycles)
    
sum(vals)
# vals
# Out:
# cycles=1
# X=1
# cycles=2
# X=1
# cycles=3
# X=1
# cycles=4
# X=1
# cycles=5
# X=6
# cycles=6
# X=6
# cycles=7
# X=37
# cycles=8
# X=37
# cycles=9
# X=7
# cycles=10
# X=7
# cycles=11
# X=9
# cycles=12
# X=9
# cycles=13
# X=16
# cycles=14
# X=16
# cycles=15
# X=16
# cycles=16
# X=16
# cycles=17
# X=12
# cycles=18
# X=12
# cycles=19
# X=17
# cycles=20
# X=17
# cycles=21
# X=23
# cycles=22
# X=23
# cycles=23
# X=23
# cycles=24
# X=22
# cycles=25
# X=22
# cycles=26
# X=27
# cycles=27
# X=27
# cycles=28
# X=26
# cycles=29
# X=26
# cycles=30
# X=31
# cycles=31
# X=31
# cycles=32
# X=32
# cycles=33
# X=32
# cycles=34
# X=32
# cycles=35
# X=37
# cycles=36
# X=37
# cycles=37
# X=37
# cycles=38
# X=36
# cycles=39
# X=36
# cycles=40
# X=1
# cycles=41
# X=1
# cycles=42
# X=4
# cycles=43
# X=4
# cycles=44
# X=4
# cycles=45
# X=6
# cycles=46
# X=6
# cycles=47
# X=9
# cycles=48
# X=9
# cycles=49
# X=7
# cycles=50
# X=7
# cycles=51
# X=9
# cycles=52
# X=9
# cycles=53
# X=9
# cycles=54
# X=17
# cycles=55
# X=17
# cycles=56
# X=14
# cycles=57
# X=14
# cycles=58
# X=19
# cycles=59
# X=19
# cycles=60
# X=2
# cycles=61
# X=2
# cycles=62
# X=24
# cycles=63
# X=24
# cycles=64
# X=22
# cycles=65
# X=22
# cycles=66
# X=24
# cycles=67
# X=24
# cycles=68
# X=29
# cycles=69
# X=29
# cycles=70
# X=27
# cycles=71
# X=27
# cycles=72
# X=1
# cycles=73
# X=1
# cycles=74
# X=32
# cycles=75
# X=32
# cycles=76
# X=34
# cycles=77
# X=34
# cycles=78
# X=39
# cycles=79
# X=39
# cycles=80
# X=-1
# cycles=81
# X=-1
# cycles=82
# X=29
# cycles=83
# X=29
# cycles=84
# X=2
# cycles=85
# X=2
# cycles=86
# X=6
# cycles=87
# X=6
# cycles=88
# X=8
# cycles=89
# X=8
# cycles=90
# X=11
# cycles=91
# X=11
# cycles=92
# X=8
# cycles=93
# X=8
# cycles=94
# X=16
# cycles=95
# X=16
# cycles=96
# X=16
# cycles=97
# X=16
# cycles=98
# X=18
# cycles=99
# X=18
# cycles=100
# X=39
# cycles=101
# X=39
# cycles=102
# X=24
# cycles=103
# X=24
# cycles=104
# X=22
# cycles=105
# X=22
# cycles=106
# X=24
# cycles=107
# X=24
# cycles=108
# X=24
# cycles=109
# X=39
# cycles=110
# X=39
# cycles=111
# X=23
# cycles=112
# X=23
# cycles=113
# X=31
# cycles=114
# X=31
# cycles=115
# X=31
# cycles=116
# X=34
# cycles=117
# X=34
# cycles=118
# X=39
# cycles=119
# X=39
# cycles=120
# X=1
# cycles=121
# X=1
# cycles=122
# X=1
# cycles=123
# X=1
# cycles=124
# X=1
# cycles=125
# X=6
# cycles=126
# X=6
# cycles=127
# X=1
# cycles=128
# X=1
# cycles=129
# X=7
# cycles=130
# X=7
# cycles=131
# X=9
# cycles=132
# X=9
# cycles=133
# X=16
# cycles=134
# X=16
# cycles=135
# X=16
# cycles=136
# X=16
# cycles=137
# X=20
# cycles=138
# X=20
# cycles=139
# X=17
# cycles=140
# X=17
# cycles=141
# X=17
# cycles=142
# X=17
# cycles=143
# X=24
# cycles=144
# X=24
# cycles=145
# X=26
# cycles=146
# X=26
# cycles=147
# X=28
# cycles=148
# X=28
# cycles=149
# X=27
# cycles=150
# X=27
# cycles=151
# X=27
# cycles=152
# X=30
# cycles=153
# X=30
# cycles=154
# X=36
# cycles=155
# X=36
# cycles=156
# X=36
# cycles=157
# X=37
# cycles=158
# X=37
# cycles=159
# X=37
# cycles=160
# X=37
# cycles=161
# X=-1
# cycles=162
# X=-1
# cycles=163
# X=-1
# cycles=164
# X=-1
# cycles=165
# X=6
# cycles=166
# X=6
# cycles=167
# X=9
# cycles=168
# X=9
# cycles=169
# X=9
# cycles=170
# X=11
# cycles=171
# X=11
# cycles=172
# X=9
# cycles=173
# X=9
# cycles=174
# X=16
# cycles=175
# X=16
# cycles=176
# X=14
# cycles=177
# X=14
# cycles=178
# X=19
# cycles=179
# X=19
# cycles=180
# X=21
# cycles=181
# X=21
# cycles=182
# X=26
# cycles=183
# X=26
# cycles=184
# X=22
# cycles=185
# X=22
# cycles=186
# X=24
# cycles=187
# X=24
# cycles=188
# X=29
# cycles=189
# X=29
# cycles=190
# X=31
# cycles=191
# X=31
# cycles=192
# X=10
# cycles=193
# X=10
# cycles=194
# X=19
# cycles=195
# X=19
# cycles=196
# X=34
# cycles=197
# X=34
# cycles=198
# X=34
# cycles=199
# X=37
# cycles=200
# X=37
# cycles=201
# X=-1
# cycles=202
# X=-1
# cycles=203
# X=6
# cycles=204
# X=6
# cycles=205
# X=6
# cycles=206
# X=6
# cycles=207
# X=24
# cycles=208
# X=24
# cycles=209
# X=7
# cycles=210
# X=7
# cycles=211
# X=11
# cycles=212
# X=11
# cycles=213
# X=11
# cycles=214
# X=12
# cycles=215
# X=12
# cycles=216
# X=14
# cycles=217
# X=14
# cycles=218
# X=19
# cycles=219
# X=19
# cycles=220
# X=22
# cycles=221
# X=22
# cycles=222
# X=22
# cycles=223
# X=22
# cycles=224
# X=36
# cycles=225
# X=36
# cycles=226
# X=27
# cycles=227
# X=27
# cycles=228
# X=27
# cycles=229
# X=27
# cycles=230
# X=31
# cycles=231
# X=31
# cycles=232
# X=32
# cycles=233
# X=32
# cycles=234
# X=32
# cycles=235
# X=36
# cycles=236
# X=36
# cycles=237
# X=39
# cycles=238
# X=39
# cycles=239
# X=39
# cycles=240
# X=31
# 15360
