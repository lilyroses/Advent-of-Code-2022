# %%
import sys
sys.path.append('..')

from get_filepath import get_filepath

# %%
FILEPATH = get_filepath(1)
# FILEPATH
# Out:
# '/home/lilyroses/code/AoC/Advent-of-Code-2022/solutions/day_1/input.txt'

# %%
with open(FILEPATH, 'r') as f:
    lines = [line.rstrip() for line in f.readlines()]

# lines

# %%
def get_calorie_list_totals(lines):
# Out:
#   Cell In[15], line 2
#
#     ^
# SyntaxError: incomplete input

# %%
all_lists = []
current_list = []
for line in lines:
    if line == '':
        all_lists.append(sum(current_list))
        current_list = []
    else:
        current_list.append(int(line))

max(all_lists)
# Out:
# 70374

# %%
lines
# Out:
# ['6750',
#  '6538',
#  '5292',
#  '4635',
#  '6855',
#  '4137',
#  '3840',
#  '4691',
#  '1633',
#  '6008',
#  '2447',
#  '1448',
#  '4061',
#  '',
#  '4261',
#  '6778',
#  '1531',
#  '2914',
#  '2102',
#  '4098',
#  '2451',
#  '1219',
#  '6488',
#  '3941',
#  '2158',
#  '',
#  '9058',
#  '3441',
#  '9318',
#  '1976',
#  '6115',
#  '9451',
#  '10090',
#  '5850',
#  '',
#  '4921',
#  '3202',
#  '3193',
#  '4170',
#  '1079',
#  '1757',
#  '5828',
#  '1757',
#  '2849',
#  '1586',
#  '5661',
#  '2607',
#  '2047',
#  '5385',
#  '',
#  '7272',
#  '20573',
#  '13163',
#  '',
#  '10682',
#  '5428',
#  '3751',
#  '9040',
#  '1556',
#  '1778',
#  '8657',
#  '9901',
#  '',
#  '4889',
#  '6751',
#  '5090',
#  '',
#  '12074',
#  '19421',
#  '3745',
#  '10856',
#  '',
#  '15209',
#  '13798',
#  '15398',
#  '15838',
#  '4569',
#  '',
#  '2572',
#  '4413',
#  '3683',
#  '12331',
#  '6840',
#  '',
#  '8924',
#  '7301',
#  '1912',
#  '7526',
#  '4090',
#  '6867',
#  '3223',
#  '1083',
#  '2215',
# ...
